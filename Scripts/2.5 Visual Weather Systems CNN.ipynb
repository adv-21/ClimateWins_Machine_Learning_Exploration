# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import operator
import matplotlib.pyplot as plt
import tensorflow as tf
from keras import Input
from keras.models import Sequential
from keras.models import Model
from keras.layers import Conv1D, Conv2D, Dense, BatchNormalization, Flatten, MaxPooling2D, Activation
from keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay

# %%
#download the weather images and put them in a directory
path = r"C:\Users\Stugots\Desktop\Multi-class Weather Dataset"
folders = os.listdir(path)
print(folders)
# Out:
# ['Cloudy', 'Rain', 'Shine', 'Sunrise']

# %%
#this will load in the pictures and rescale them to 250x250pixels

datagenerator = ImageDataGenerator(rescale=1/255, validation_split=0.2)
train_generator = datagenerator.flow_from_directory(
    path,
    target_size=(250 , 250),
    batch_size=32,
    subset='training',
)

test_generator = datagenerator.flow_from_directory(
    path,
    target_size=(250 , 250),
    batch_size=32,
    subset='validation',
)
# Out:
# Found 901 images belonging to 4 classes.
# Found 224 images belonging to 4 classes.

# %%
#this is a CNN to categorize the weather images

inputs = Input(shape=(250, 250, 3))

x = Conv2D(32, (5,5), activation = 'relu')(inputs)
x = MaxPooling2D(3,3)(x)
x = Conv2D(64, (5,5) , activation = 'relu')(x)
x = MaxPooling2D((3,3))(x)
x = Conv2D(128 , (5,5) , activation = 'relu')(x)
x = MaxPooling2D(3,3)(x)
x = Flatten()(x)
x = Dropout(0.5, seed = 5)(x)
x = Dense(128 , activation = 'relu')(x)

outputs = Dense(4, activation = 'softmax')(x)

model:Model = Model(inputs=inputs, outputs=outputs)

# %%
#compile and run the model
#how many epochs are required to generate an accurate model?

model.compile(optimizer="Adam", loss="mean_squared_error", metrics=["accuracy"])
model.fit(
    train_generator, 
    epochs = 50, #<----FILL THIS IN!
    steps_per_epoch = train_generator.n // train_generator.batch_size,
    validation_data = test_generator,
    validation_steps = test_generator.n // test_generator.batch_size,
)
# Out:
# Epoch 1/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 244ms/step - accuracy: 0.9678 - loss: 0.0143 - val_accuracy: 0.8616 - val_loss: 0.0610
# Epoch 2/50
#  1/28 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - accuracy: 0.9688 - loss: 0.0176
# C:\Users\Stugots\anaconda3\envs\quandl-env\lib\site-packages\keras\src\trainers\epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9688 - loss: 0.0176 - val_accuracy: 0.8571 - val_loss: 0.0633
# Epoch 3/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 228ms/step - accuracy: 0.9781 - loss: 0.0110 - val_accuracy: 0.8705 - val_loss: 0.0509
# Epoch 4/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9375 - loss: 0.0298 - val_accuracy: 0.8839 - val_loss: 0.0485
# Epoch 5/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 230ms/step - accuracy: 0.9666 - loss: 0.0120 - val_accuracy: 0.8661 - val_loss: 0.0525
# Epoch 6/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9688 - loss: 0.0231 - val_accuracy: 0.8616 - val_loss: 0.0573
# Epoch 7/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 230ms/step - accuracy: 0.9563 - loss: 0.0180 - val_accuracy: 0.8438 - val_loss: 0.0713
# Epoch 8/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9688 - loss: 0.0183 - val_accuracy: 0.8125 - val_loss: 0.0792
# Epoch 9/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 225ms/step - accuracy: 0.9586 - loss: 0.0181 - val_accuracy: 0.8214 - val_loss: 0.0790
# Epoch 10/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9062 - loss: 0.0370 - val_accuracy: 0.7991 - val_loss: 0.0870
# Epoch 11/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 227ms/step - accuracy: 0.9551 - loss: 0.0208 - val_accuracy: 0.8571 - val_loss: 0.0595
# Epoch 12/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9688 - loss: 0.0068 - val_accuracy: 0.8616 - val_loss: 0.0586
# Epoch 13/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 221ms/step - accuracy: 0.9804 - loss: 0.0097 - val_accuracy: 0.8750 - val_loss: 0.0552
# Epoch 14/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 1.3079e-04 - val_accuracy: 0.8616 - val_loss: 0.0566
# Epoch 15/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 228ms/step - accuracy: 0.9735 - loss: 0.0104 - val_accuracy: 0.8839 - val_loss: 0.0507
# Epoch 16/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 2.6266e-05 - val_accuracy: 0.8839 - val_loss: 0.0499
# Epoch 17/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 228ms/step - accuracy: 0.9827 - loss: 0.0084 - val_accuracy: 0.8884 - val_loss: 0.0526
# Epoch 18/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.8929 - val_loss: 0.0527
# Epoch 19/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 229ms/step - accuracy: 0.9816 - loss: 0.0082 - val_accuracy: 0.8661 - val_loss: 0.0550
# Epoch 20/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 9.7534e-04 - val_accuracy: 0.8705 - val_loss: 0.0567
# Epoch 21/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 224ms/step - accuracy: 0.9770 - loss: 0.0088 - val_accuracy: 0.8571 - val_loss: 0.0533
# Epoch 22/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.8839 - val_loss: 0.0480
# Epoch 23/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.9678 - loss: 0.0123 - val_accuracy: 0.8661 - val_loss: 0.0475
# Epoch 24/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9688 - loss: 0.0176 - val_accuracy: 0.8527 - val_loss: 0.0632
# Epoch 25/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 234ms/step - accuracy: 0.9160 - loss: 0.0325 - val_accuracy: 0.8348 - val_loss: 0.0714
# Epoch 26/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9688 - loss: 0.0253 - val_accuracy: 0.8571 - val_loss: 0.0648
# Epoch 27/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - accuracy: 0.9241 - loss: 0.0299 - val_accuracy: 0.7723 - val_loss: 0.1033
# Epoch 28/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9688 - loss: 0.0140 - val_accuracy: 0.7679 - val_loss: 0.0932
# Epoch 29/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.9007 - loss: 0.0349 - val_accuracy: 0.8705 - val_loss: 0.0543
# Epoch 30/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.8000 - loss: 0.0442 - val_accuracy: 0.8616 - val_loss: 0.0510
# Epoch 31/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - accuracy: 0.9436 - loss: 0.0202 - val_accuracy: 0.8214 - val_loss: 0.0846
# Epoch 32/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9688 - loss: 0.0156 - val_accuracy: 0.8214 - val_loss: 0.0829
# Epoch 33/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 226ms/step - accuracy: 0.9678 - loss: 0.0131 - val_accuracy: 0.8527 - val_loss: 0.0697
# Epoch 34/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9688 - loss: 0.0087 - val_accuracy: 0.8393 - val_loss: 0.0713
# Epoch 35/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 224ms/step - accuracy: 0.9701 - loss: 0.0127 - val_accuracy: 0.8348 - val_loss: 0.0673
# Epoch 36/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9688 - loss: 0.0177 - val_accuracy: 0.8214 - val_loss: 0.0664
# Epoch 37/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 226ms/step - accuracy: 0.9735 - loss: 0.0107 - val_accuracy: 0.8170 - val_loss: 0.0768
# Epoch 38/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9375 - loss: 0.0266 - val_accuracy: 0.8080 - val_loss: 0.0761
# Epoch 39/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 231ms/step - accuracy: 0.9655 - loss: 0.0138 - val_accuracy: 0.8482 - val_loss: 0.0580
# Epoch 40/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9688 - loss: 0.0139 - val_accuracy: 0.8482 - val_loss: 0.0578
# Epoch 41/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 227ms/step - accuracy: 0.9747 - loss: 0.0118 - val_accuracy: 0.8884 - val_loss: 0.0427
# Epoch 42/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9688 - loss: 0.0173 - val_accuracy: 0.8884 - val_loss: 0.0420
# Epoch 43/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 228ms/step - accuracy: 0.9770 - loss: 0.0095 - val_accuracy: 0.8705 - val_loss: 0.0515
# Epoch 44/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.8884 - val_loss: 0.0473
# Epoch 45/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 224ms/step - accuracy: 0.9804 - loss: 0.0085 - val_accuracy: 0.8795 - val_loss: 0.0558
# Epoch 46/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.8839 - val_loss: 0.0537
# Epoch 47/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 225ms/step - accuracy: 0.9816 - loss: 0.0083 - val_accuracy: 0.8616 - val_loss: 0.0566
# Epoch 48/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 4.6140e-04 - val_accuracy: 0.8616 - val_loss: 0.0573
# Epoch 49/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - accuracy: 0.9839 - loss: 0.0074 - val_accuracy: 0.8750 - val_loss: 0.0535
# Epoch 50/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9688 - loss: 0.0205 - val_accuracy: 0.8795 - val_loss: 0.0532

# %%
results = pd.DataFrame(model.history.history)

# %%
results[['loss','val_loss']].plot(title='Model Loss')
plt.savefig('./loss.png')

# %%
results[['accuracy','val_accuracy']].plot(title='Model Acurracy')
plt.savefig('./accuracy.png')

# %%
# Print the accuracy and loss
print("Accuracy: {}, Val_Accuracy: {}".format(results['accuracy'].iloc[-1], results['val_accuracy'].iloc[-1]))
print("Loss: {}, Val_Loss: {}".format(results['loss'].iloc[-1], results['val_loss'].iloc[-1]))
# Out:
# Accuracy: 0.8929804563522339, Val_Accuracy: 0.8125
# Loss: 0.03844152018427849, Val_Loss: 0.0719316154718399

# %%
# collect n batches of images and display the confusion matrix for them.

class_names = ['Cloudy', 'Rain', 'Shine', 'Sunrise']
n = 10 #<--you can change the number of batches selected.

image_batch, classes_batch = next(test_generator)

for batch in range(n):
    temp = next(test_generator)
    image_batch = np.concatenate((image_batch, temp[0]))
    classes_batch = np.concatenate((classes_batch, temp[1]))

classes_batch = classes_batch
y_predict = model.predict(image_batch)

#Confusion matrix for training data
cm = confusion_matrix(y_pred = [np.argmax(x) for x in y_predict], y_true = [np.argmax(x) for x in classes_batch])
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step

# %%
#This function will display a number of random images as well as the predictions for the type of weather.

def predict_one(model, num_images = None):  
    image_batch, classes_batch = next(test_generator)
    predicted_batch = model.predict(image_batch)
    for k in range(0,image_batch.shape[0] if num_images is None else num_images):
        image = image_batch[k]
        real_class = class_names[np.argmax(classes_batch[k])]
        predicted_class = class_names[np.argmax(predicted_batch[k])]
        value_predicted = predicted_batch[k]
        isTrue = (real_class == predicted_class)
        plt.figure(k)
        plt.title(str("Correct Prediction" if isTrue else "Incorrect Prediction") + ' - class: ' + real_class + ' - ' + 'predicted: ' + predicted_class + str(value_predicted))
        plt.axis('off')
        plt.savefig('./' + real_class + '_' + predicted_class + '_' + str(value_predicted) + '.png')
        plt.imshow(image)

# %%
predict_one(model, 1) #<--you can show multiple pictures with this command. Just fill in the number you want to see.
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
